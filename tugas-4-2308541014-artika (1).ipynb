# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
makanan = ['pizza','bakmi','mie ayam','trangbulan']
print(makanan)
print(makanan[1])
print(makanan[3])
print(makanan[-3])
print(makanan[-4])
# Out:
# ['pizza', 'bakmi', 'mie ayam', 'trangbulan']
# bakmi
# trangbulan
# bakmi
# pizza

# %%
makanan[1]= 'spagethi'
print(makanan)
# Out:
# ['pizza', 'spagethi', 'mie ayam', 'trangbulan']

# %%
print(makanan[0:5])
# Out:
# ['pizza', 'spagethi', 'mie ayam', 'trangbulan']

# %%
# tidak merubah list
print(makanan)
# Out:
# ['pizza', 'spagethi', 'mie ayam', 'trangbulan']

# %%
nama_bulan = ['februari','maret','april','mei','juni']
nama_bulan.append('juli, agustus, september, oktober, november, desember')
print(nama_bulan)
# Out:
# ['februari', 'maret', 'april', 'mei', 'juni', 'juli, agustus, september, oktober, november, desember']

# %%
nama_bulan.insert(0,'januari')
print(nama_bulan)
# Out:
# ['januari', 'februari', 'maret', 'april', 'mei', 'juni', 'juli, agustus, september, oktober, november, desember']

# %%
nama_bulan.remove('maret')
print(nama_bulan)
# Out:
# ['februari', 'april', 'mei', 'juni', 'juli, agustus, september, oktober, november, desember']

# %%
print('maret'in nama_bulan)
# Out:
# False

# %%
print('februari'in nama_bulan)
# Out:
# True

# %%
print(len(nama_bulan))
# Out:
# 5

# %%
warna_rambut = ['ash blonde','golden brown','coklat caramel','cranberry red']
for jenis in warna_rambut:
    print(jenis)
# Out:
# ash blonde
# golden brown
# coklat caramel
# cranberry red

# %%
i= 2
while i < len(warna_rambut):
    print(warna_rambut[i])
    i+=1
# Out:
# coklat caramel
# cranberry red
