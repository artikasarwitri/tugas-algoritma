# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
jumlah_judul = input ("pilih jumlah judul film")
film_yang_diinginkan = input ("pilih judul film yang diinginkan")
peran_yang_diinginkan = input("pilih peran yang diinginkan")
print("silahkan tunggu sampai di acc oleh sutradara")
print("semangat berjuang!!")
# Out:
# pilih jumlah judul film 2
# pilih judul film yang diinginkan bawang merah bawang putih, magic five
# pilih peran yang diinginkan protagonis
# silahkan tunggu sampai di acc oleh sutradara
# semangat berjuang!!

# %%
undangan = ("upacara potong gigi")
jumlah = input("sebar undangan dengan jumlah tamu yang diinginkan")
lokasi = input("pilih lokasi resepsi yang diinginkan")
waktu = input ("pilih waktu yang terbaik saat upacara potong gigi")
print ("jangan lupa datang semeton!!!")
# Out:
# sebar undangan dengan jumlah tamu yang diinginkan 200
# pilih lokasi resepsi yang diinginkan karangasem subagan
# pilih waktu yang terbaik saat upacara potong gigi pukul 9 wita - selesai
# jangan lupa datang semeton!!!

# %%
penumpang_pesawat = 200
jumlah_pesawat = 4
jenis_pesawat = 'airbus A330-300'
tujuan = 'korea selatan'
biaya = 17000000
print(penumpang_pesawat * jumlah_pesawat * biaya)
# Out:
# 13600000000

# %%
harga_apel_2_kilo = 26000
harga_jeruk_2_kilo = 24000
harga_manggis_2_kilo = 40000
print(harga_apel_2_kilo + harga_jeruk_2_kilo + harga_manggis_2_kilo  )
# Out:
# 90000

# %%
bola_artika = 20
bola_mei = 24
nilai_bola_artika = 100
ditanya = 'jumlah bola mei?'
print(bola_mei / bola_artika * nilai_bola_artika)
# Out:
# 120.0

# %%
idol_korea_selatan = input("sebutkan idol korea yang kamu sukai!!")
grup_band = input("dari grup band mana idol koreamu berasal?")
tahun_suka_kpop = input("sejak tahun berapa kamu menyukai kpop?")
print("semoga kamu bisa secepatnya bertemu dengan idola yang kamu impikan ")
# Out:
# sebutkan idol korea yang kamu sukai!! taehyung, jaehyun,yeonjun,jay,mingyu
# dari grup band mana idol koreamu berasal? bts,nct,txt,enhypen,seventeen
# sejak tahun berapa kamu menyukai kpop? 2015
# semoga kamu bisa secepatnya bertemu dengan idola yang kamu impikan
