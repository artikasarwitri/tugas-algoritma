# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama_artis = "Kim Jisoo"
judul_drakor = 'Snowdrop'
lawan_main = 'Jung Hae-in'
print(nama_artis +'menjadi pemeran utama'+'di drama korea'+judul_drakor+'bersama'+lawan_main)

# %%
trangbulan = 'ini trangbulan rasa coklat keju'
print(trangbulan[0:3])
print(trangbulan[0:-3])
print(trangbulan[7:-2])
print(trangbulan[9:-5])
print(trangbulan[3:-2:1])
print(trangbulan[:-7])
print(trangbulan[10:])
print(trangbulan[:])
# Out:
# ini
# ini trangbulan rasa coklat k
# ngbulan rasa coklat ke
# bulan rasa coklat
#  trangbulan rasa coklat ke
# ini trangbulan rasa cokl
# ulan rasa coklat keju
# ini trangbulan rasa coklat keju

# %%
quotes = 'Tujuan Hidup Adalah Memberi Hidupmu Tujuan'
print(len(quotes))
# Out:
# 42

# %%
quotes.upper()
# Out:
# 'TUJUAN HIDUP ADALAH MEMBERI HIDUPMU TUJUAN'

# %%
quotes.lower()
# Out:
# 'tujuan hidup adalah memberi hidupmu tujuan'

# %%
quotes.find('hidup')
# Out:
# 7

# %%
quotes.replace('tujuan', 'kebebasan')
# Out:
# 'Kebebasan Hidup Adalah Memberi Hidupmu Kebebasan'

# %%
quotes.replace('kebebasan', 'tujuan')
# Out:
# 'Tujuan Hidup Adalah Memberi Hidupmu Tujuan'

# %%
print('Memberi'in quotes)
# Out:
# True

# %%
print('memberi'in quotes)
# Out:
# False

# %%
harga_pulpen_dikali_jumlah_pulpen = 1500*2
print(harga_pulpen_dikali_jumlah_pulpen)
harga_penghapus_dikali_jumlah_pengapus = 2000*1
print(harga_penghapus_dikali_jumlah_pengapus)
harga_pensil_dikali_jumlah_pensil = 2000*3
print(harga_pensil_dikali_jumlah_pensil)
total = 1500*2 + 2000*1 + 2000*3
print(total)

# %%
apel_jeruk= 3 < 6
print(apel_jeruk)
mangga_jambu = 5 > 3
print(mangga_jambu)
nanas_durian = 6 > 10
print(nanas_durian)
anggur_pir = 7>10
print(anggur_pir)
melon_pisang = 1>3
print(melon_pisang)
# Out:
# True
# True
# False
# False
# False

# %%
jam_tangan = 25
jam_dinding = 15
print(jam_tangan > 20 and jam_dinding < 25)
print(jam_tangan < 20 or jam_dinding < 25)
print(jam_tangan < 20 or jam_dinding > 25)
print(not jam_tangan < 20 or jam_dinding > 25)
# Out:
# True
# True
# False
# True
